# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswin-k61/pytorch-projects/blob/main/Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
tensor_a=torch.tensor([5,6,8,9])
tensor_b=torch.tensor([9,8,4,2])

# %%
tensor_a+tensor_b
# Out:
# tensor([14, 14, 12, 11])

# %%
torch.add(tensor_a,tensor_b)
# Out:
# tensor([14, 14, 12, 11])

# %%
tensor_a-tensor_b
# Out:
# tensor([-4, -2,  4,  7])

# %%
torch.sub(tensor_a,tensor_b)
# Out:
# tensor([-4, -2,  4,  7])

# %%
tensor_a*tensor_b
# Out:
# tensor([45, 48, 32, 18])

# %%
torch.mul(tensor_a,tensor_b)
# Out:
# tensor([45, 48, 32, 18])

# %%
tensor_a/tensor_b
# Out:
# tensor([0.5556, 0.7500, 2.0000, 4.5000])

# %%
torch.div(tensor_a,tensor_b)
# Out:
# tensor([0.5556, 0.7500, 2.0000, 4.5000])

# %%
torch.pow(tensor_a,tensor_b)
# Out:
# tensor([1953125, 1679616,    4096,      81])

# %%
torch.remainder(tensor_a,tensor_b)
# Out:
# tensor([5, 6, 0, 1])

# %%
tensor_a.add(tensor_b)
# Out:
# tensor([14, 14, 12, 11])

# %%
#Reassigning
#tensor_a=tensor_a+tensor_b
tensor_a.add_(tensor_b)
# Out:
# tensor([14, 14, 12, 11])

# %%
tensor_a
# Out:
# tensor([14, 14, 12, 11])
